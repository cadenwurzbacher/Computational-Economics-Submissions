# %%
import pandas as pd

# %%
professional_dict =  {"Jordan Peterson":{"Area of Expertise":"Psychology", 
                                     "Bio":"Dr. Jordan B. Peterson is a professor of psychology at the University of Toronto, a clinical psychologist, and the author of the bestsellers Beyond Order: 12 More Rules for Life & 12 Rules for Life: An Antidote to Chaos, #1 for nonfiction in 2018 in the US, Canada, the UK, Australia, New Zealand, Sweden, the Netherlands, Brazil and Norway, and slated for translation into 50 languages.",
                                     "Website":"https://www.jordanbpeterson.com/"},
                      "Elon Musk":{"Area of Expertise":"Engineering, Entrepreneurship", 
                                     "Bio":"Elon Musk co-founded and leads Tesla, SpaceX, Neuralink and The Boring Company. As the co-founder and CEO of Tesla, Elon leads all product design, engineering and global manufacturing of the company's electric vehicles, battery products and solar energy products.",
                                     "Website":"https://twitter.com/elonmusk?ref_src=twsrc%5Egoogle%7Ctwcamp%5Eserp%7Ctwgr%5Eauthor"},
                      "Doug Burgum":{"Area of Expertise":"Technology, Entrepreneurship, Political Leadership", 
                                     "Bio":"Doug Burgum",
                                     "Website":"https://www.dougburgum.com/"},
                      "Bill Gates":{"Area of Expertise":"Technology, Entrepreneur", 
                                     "Bio":"Bill Gates is a technologist, business leader, and philanthropist. He grew up in Seattle, Washington, with an amazing and supportive family who encouraged his interest in computers at an early age. He dropped out of college to start Microsoft with his childhood friend Paul Allen. Today, Bill co-chairs the Bill & Melinda Gates Foundation with Melinda French Gates, where he works to give his wealth back to society.",
                                     "Website":"https://www.gatesnotes.com"},
                      "Arnold Schwarzenegger":{"Area of Expertise":"Bodybuilder, Governor, Actor", 
                                     "Bio":"ARNOLD SCHWARZENEGGER is known all over the globe for his many accomplishments: world champion bodybuilder, Hollywood action hero, successful businessman, environmentalist, philanthropist, best-selling author, and California's 38th Governor. This world-famous athlete and actor was born in Thal, Austria in 1947, and by the age of 20 was dominating the sport of competitive bodybuilding, becoming the youngest person ever to win the Mr. Universe title.",
                                     "Website":"http://www.schwarzenegger.com"},
                      "Leonardo DiCaprio":{"Area of Expertise":"Actor", 
                                     "Bio":"Leonardo DiCaprio is an award-winning actor and a three-time Academy Award® nominee.  DiCaprio’s 5th collaboration with Director Martin Scorsese “The Wolf of Wall Street” is available on Blu-ray & DVD now. DiCaprio starred as Jay Gatsby in “The Great Gatsby”, directed by Baz Luhrmann.  Golden Globe, Critics’ Choice and Screen Actors Guild (SAG) Award® nominations for his work in the film.",
                                     "Website":"https://leonardodicaprio.com"},
                      "Matt D\'Avella":{"Area of Expertise":"Filmmaker", 
                                     "Bio":"Matt D’Avella is a  Netflix filmmaker, YouTuber & entrepreneur that explores things like minimalism, productivity, and habits.",
                                     "Website":"https://www.mattdavella.com/"},
                      "Herb Brooks":{"Area of Expertise":"Hockey Coach", 
                                     "Bio":"Born on August 5, 1937, Herb Brooks grew up in a modest duplex at the corner of Payne and Ivy Streets, on the East side of St. Paul. Herbie went on to play on several U.S. National and Olympic teams from 1962-70. The next stop for Brooks is the one that will forever be linked to his legacy, the fabled 1980 U.S. Olympic team which won the gold medal at Lake Placid, NY. The Miracle on Ice would later be named as the best sporting event of the 20th century.",
                                     "Website":"https://www.herbbrooksfoundation.com"},
                      "Alan Watts":{"Area of Expertise":"Psychology, Public Speaking", 
                                     "Bio":"A prolific author and speaker, Alan Watts was one of the first to interpret Eastern wisdom for a Western audience. Born outside London in 1915, he discovered the nearby Buddhist Lodge at a young age. After moving to the United States in 1938, Alan became an Episcopal priest for a time, and then relocated to Millbrook, New York, where he wrote his pivotal book The Wisdom of Insecurity: A Message for an Age of Anxiety.",
                                     "Website":"https://alanwatts.org"},
                      "J.D. Vance":{"Area of Expertise":"Lawyer, Author", 
                                     "Bio":"JD served our nation in the Iraq War as a proud Marine, graduated from The Ohio State University, received his law degree from Yale Law School, and became a successful investor in Silicon Valley. He wrote a bestselling book, Hillbilly Elegy, which was turned into a movie on Netflix.",
                                     "Website":"https://jdvance.com/"}}

# %%
professional_dict
# Out:
# {'Jordan Peterson': {'Area of Expertise': 'Psychology',
#   'Bio': 'Dr. Jordan B. Peterson is a professor of psychology at the University of Toronto, a clinical psychologist, and the author of the bestsellers Beyond Order: 12 More Rules for Life & 12 Rules for Life: An Antidote to Chaos, #1 for nonfiction in 2018 in the US, Canada, the UK, Australia, New Zealand, Sweden, the Netherlands, Brazil and Norway, and slated for translation into 50 languages.',
#   'Website': 'https://www.jordanbpeterson.com/'},
#  'Elon Musk': {'Area of Expertise': 'Engineering, Entrepreneurship',
#   'Bio': "Elon Musk co-founded and leads Tesla, SpaceX, Neuralink and The Boring Company. As the co-founder and CEO of Tesla, Elon leads all product design, engineering and global manufacturing of the company's electric vehicles, battery products and solar energy products.",
#   'Website': 'https://twitter.com/elonmusk?ref_src=twsrc%5Egoogle%7Ctwcamp%5Eserp%7Ctwgr%5Eauthor'},
# ...

# %%
professional_df = pd.DataFrame(professional_dict)

# %%
professional_df.T
# Out:
#                                                        Area of Expertise  \
# Jordan Peterson                                               Psychology
# Elon Musk                                  Engineering, Entrepreneurship
# Doug Burgum            Technology, Entrepreneurship, Political Leader...
# Bill Gates                                      Technology, Entrepreneur
# Arnold Schwarzenegger                       Bodybuilder, Governor, Actor
# Leonardo DiCaprio                                                  Actor
# Matt D'Avella                                                  Filmmaker
# Herb Brooks                                                 Hockey Coach
# Alan Watts                                   Psychology, Public Speaking
# J.D. Vance                                                Lawyer, Author
#
#                                                                      Bio  \
# Jordan Peterson        Dr. Jordan B. Peterson is a professor of psych...
# ...

# %%
professional_df.to_csv("ProfessionalInfo.csv")
